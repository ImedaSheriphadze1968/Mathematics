# %% [markdown]
# **🔷 Что делает программа LogiScale**
#
# **LogiScale** — это интеллектуальный калькулятор и визуализатор новой бинарной операции ⊛, основанной на логарифмическом взаимодействии между числами. В отличие от обычного сложения или умножения, эта операция моделирует непропорциональный, асимметричный рост, что делает её особенно ценной при описании реальных процессов, где результат не зависит напрямую от простого увеличения чисел.
#
# **🔹 Как работает операция a ⊛ b:**
#
# ![1.PNG](data:image/png;base64,...)
#
# 1. a — это количество ресурса, например, информации, энергии, денег, внимания и т.д.
#
# 2. b — это масштаб восприятия, система координат или внешняя среда.
#
# 3. log_b(a + b) — отражает, как система реагирует на увеличение a в контексте масштаба b.
#
# **🎯 Практическое применение LogiScale в современной жизни**
# 1. 🧠 **Искусственный интеллект и машинное обучение**
#    1. Проблема: При обучении нейросетей часто возникает эффект насыщения — увеличение данных или веса параметров не даёт соответствующего эффекта.
#
#   2. Решение с LogiScale: Использование ⊛ позволяет логарифмически масштабировать влияние входов, избегая переобучения и «взрывов градиентов».
#
# 2. **📈 Когнитивные и поведенческие науки**
#    1. Применение: Моделирование ментальной перегрузки, порогов восприятия, психофизиологических реакций на раздражители.
#
#    2. Пример: Как изменяется внимание человека при увеличении количества информации — линейная модель неэффективна, а ⊛ точно имитирует эффект насыщения.
#
# 3. **🔐 Криптография**
#    1. Инновация: Создание нерегулярных криптографических ключей, где величина ключа зависит от нестандартной логики роста.
#
#    2. Преимущество: Повышенная стойкость к атаке за счёт непредсказуемости результата a ⊛ b.
#
# 4. **⚙️ Экономика и управление ресурсами**
#    1. Применение: Оценка отдачи от инвестиций при увеличении вложений в ограниченной системе.
#
#    2. Пример: При вложении a единиц в проект масштаба b, LogiScale покажет реальную (логарифмическую) отдачу, которая снижается при достижении насыщения.
#
# 5. **📚 Образование и научная визуализация**
#    1. Использование: Обучение студентов нестандартным моделям роста.
#
#    2. Графики и примеры: визуализация асимметрии, ростовых порогов и сложных зависимостей между величинами.
#
# **💻 Как использовать программу**
# 1. 🧮 Ввод данных: Пользователь вводит значения a и b, соблюдая условие a > 0, b > 1.
# 2. ⚙️ Расчёт: Программа вычисляет a ⊛ b по формуле.
# 3. 📈 Визуализация: Строится график зависимости результата от изменения a при фиксированном b.
# 4. ✅ Анализ результата: Пользователь видит, как меняется логарифмическое взаимодействие при различных условиях.
#
# **📌 Пример использования**
#
# Введите значение a: 50
# Введите значение b: 10
#
# 📈 Результат: a ⊛ b = 50 × log_10(60) ≈ 50 × 1.778 ≈ 88.9
#
# 👉 Это означает, что при вложении **50** единиц ресурса в систему масштаба **10**, эффект будет равен **88.9** условных единиц, а не **100** или **500**, как в линейных/мультипликативных моделях.

# %%
import math
import matplotlib.pyplot as plt
import numpy as np

def logiscale_operation(a: float, b: float) -> float:
    if a <= 0 or b <= 1:
        raise ValueError("❌ Введите: a > 0, b > 1")
    return a * math.log(a + b, b)

def draw_graph(a_val, b_val):
    x = np.linspace(0.1, 100, 400)
    y = [logiscale_operation(xi, b_val) for xi in x]

    plt.figure(figsize=(10, 6))
    plt.plot(x, y, label=f"b = {b_val}", linewidth=2, color="blue")
    plt.axvline(a_val, linestyle="--", color="red", label=f"Точка a = {a_val}")
    plt.axhline(logiscale_operation(a_val, b_val), linestyle="--", color="green")
    plt.title("🔷 График логарифмической операции: a ⊛ b", fontsize=16)
    plt.xlabel("Значение a")
    plt.ylabel("Результат a ⊛ b")
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.show()

def main():
    print("📐 Интерактивная операция логарифмического взаимодействия (a ⊛ b)")
    try:
        a = float(input("Введите значение a (> 0): "))
        b = float(input("Введите значение b (> 1): "))
        result = logiscale_operation(a, b)

        print("\n📊 Результат операции:")
        print("━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━")
        print(f"🔹 Формула:  a ⊛ b = a × log_b(a + b)")
        print(f"🔸 Ввод:     a = {a}, b = {b}")
        print(f"✅ Ответ:    {result:.5f}")
        print("━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━")

        draw_graph(a, b)

    except ValueError as ve:
        print(f"❌ Ошибка: {ve}")
    except Exception as e:
        print(f"⚠️ Непредвиденная ошибка: {e}")

if __name__ == "__main__":
    main()
# Out:
# 📐 Интерактивная операция логарифмического взаимодействия (a ⊛ b)
# Введите значение a (> 0): 256
# Введите значение b (> 1): 678
#
# 📊 Результат операции:
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🔹 Формула:  a ⊛ b = a × log_b(a + b)
# 🔸 Ввод:     a = 256.0, b = 678.0
# ✅ Ответ:    268.57899
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# <ipython-input-1-078b087729a2>:23: UserWarning: Glyph 128311 (\N{LARGE BLUE DIAMOND}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128311 (\N{LARGE BLUE DIAMOND}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# **✅ Вывод**
# Программа **LogiScale** — это:
#
# интеллектуальный инструмент для моделирования сложных взаимодействий;
#
# образовательный и аналитический инструмент;
#
# практическое приложение для **ИИ**, **психологии**, **экономики** и **науки**.
#
# 🎯 Она делает невидимые закономерности видимыми, позволяет анализировать рост, управлять сложными системами и визуализировать закономерности, которые невозможно описать обычной арифметикой.
